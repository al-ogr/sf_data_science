# %% [markdown]
# # PYTHON-12. Продвинутые методы работы с данными в Pandas

# %% [markdown]
# Считывание данных:

# %%
import pandas as pd
import numpy as np

melb_df = pd.read_csv('./data/melb_data_fe.csv')
display(melb_df.head())
melb_df.info()
# Out:
#        Suburb  Rooms   Type      Price Method SellerG        Date  Distance  \
# 0  Abbotsford      2  house  1480000.0      S  Biggin  2016-03-12       2.5
# 1  Abbotsford      2  house  1035000.0      S  Biggin  2016-04-02       2.5
# 2  Abbotsford      3  house  1465000.0     SP  Biggin  2017-04-03       2.5
# 3  Abbotsford      3  house   850000.0     PI  Biggin  2017-04-03       2.5
# 4  Abbotsford      4  house  1600000.0     VB  Nelson  2016-04-06       2.5
#
#    Postcode  Bedroom  ...  Longtitude             Regionname  Propertycount  \
# 0      3067        2  ...    144.9984  Northern Metropolitan           4019
# 1      3067        2  ...    144.9934  Northern Metropolitan           4019
# 2      3067        3  ...    144.9944  Northern Metropolitan           4019
# 3      3067        3  ...    144.9969  Northern Metropolitan           4019
# 4      3067        3  ...    144.9941  Northern Metropolitan           4019
#
# ...

# %% [markdown]
# 1.1 Преобразуйте столбец Date в формат datetime и выделите квартал (quarter) продажи объектов недвижимости. Найдите второй по популярности квартал продажи. В качестве ответа запишите число объектов, проданных в этом квартале.

# %%
melb_df['Date'] = pd.to_datetime(melb_df['Date'], dayfirst=False)
melb_df['Date'].info()
quarter = melb_df['Date'].dt.quarter
quarter.value_counts().iloc[1]
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 13580 entries, 0 to 13579
# Series name: Date
# Non-Null Count  Dtype
# --------------  -----
# 13580 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 106.2 KB
# np.int64(4359)

# %% [markdown]
# 1.2 Преобразуйте все столбцы, в которых меньше 150 уникальных значений, в тип данных category, исключив из преобразования столбцы Date, Rooms, Bedroom, Bathroom, Car.
# В качестве ответа запишите результирующее количество столбцов, которые имеют тип данных category.

# %%
for col in melb_df.columns:
    if melb_df[col].nunique() < 150 and col not in ['Date', 'Rooms', 'Bedroom', 'Bathroom', 'Car']:
        melb_df[col] = melb_df[col].astype('category')
melb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  category
#  1   Rooms            13580 non-null  int64
#  2   Type             13580 non-null  category
#  3   Price            13580 non-null  float64
#  4   Method           13580 non-null  category
#  5   SellerG          13580 non-null  category
#  6   Date             13580 non-null  datetime64[ns]
#  7   Distance         13580 non-null  float64
#  8   Postcode         13580 non-null  int64
#  9   Bedroom          13580 non-null  int64
#  10  Bathroom         13580 non-null  int64
#  11  Car              13580 non-null  int64
#  12  Landsize         13580 non-null  float64
#  13  BuildingArea     13580 non-null  float64
#  14  CouncilArea      12211 non-null  category
#  15  Lattitude        13580 non-null  float64
# ...

# %% [markdown]
# 2.2 Произведите сортировку столбца AreaRatio по убыванию. При этом индексы полученной таблицы замените на новые. Какое значение площади здания находится в строке 1558? Ответ округлите до целого числа.

# %%
melb_df.sort_values(by='AreaRatio', ascending=False, ignore_index=True).loc[1558, ['BuildingArea']]
# Out:
# BuildingArea    126.0
# Name: 1558, dtype: object

# %% [markdown]
# 2.3 Найдите таунхаусы (Type) с количеством жилых комнат (Rooms) больше 2. Отсортируйте полученную таблицу сначала по возрастанию числа комнат, а затем по убыванию средней площади комнат (MeanRoomsSquare). Индексы таблицы замените на новые. Какая цена будет у объекта в строке 18? Ответ запишите в виде целого числа.

# %%
melb_df[(melb_df['Type'] == 'townhouse') & (melb_df['Rooms'] > 2)].sort_values(by=['Rooms', 'MeanRoomsSquare'], ascending=[True, False], ignore_index=True).loc[18, 'Price']
# Out:
# np.float64(1300000.0)

# %% [markdown]
# 3.1 Сгруппируйте данные по признаку количества комнат и найдите среднюю цену объектов недвижимости в каждой группе. В качестве ответа запишите количество комнат, для которых средняя цена наибольшая.

# %%
melb_df.groupby('Rooms')['Price'].mean().sort_values(ascending=False).index[0]
# Out:
# np.int64(7)

# %% [markdown]
# 3.2 Какой регион имеет наименьшее стандартное отклонение по географической широте (Lattitude)?
# В качестве ответа запишите название этого региона.

# %%
melb_df.groupby(by='Regionname')['Lattitude'].std().sort_values().index[0]
# Out:
# C:\Users\g-022\AppData\Local\Temp\ipykernel_1316\3447855144.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby(by='Regionname')['Lattitude'].std().sort_values().index[0]
# 'Western Victoria'

# %% [markdown]
# 3.3 Какая риелторская компания (SellerG) имеет наименьшую общую выручку за период с 1 мая по 1 сентября (включительно) 2017 года?
# Для ответа на этот вопрос рассчитайте сумму продаж (Price) каждой компании в заданный период.
# Не забудьте перевести даты в формат datetime.

# %%
melb_df[(melb_df['Date'] <= pd.to_datetime("2017-09-01")) 
        & (melb_df['Date'] >= pd.to_datetime("2017-05-01"))].groupby(by='SellerG')['Price']\
            .sum().sort_values().index[0]
# Out:
# C:\Users\g-022\AppData\Local\Temp\ipykernel_1316\1957545402.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df[(melb_df['Date'] <= pd.to_datetime("2017-09-01"))
# 'LITTLE'

# %% [markdown]
# Давайте построим таблицу, в которой по индексам будут располагаться признаки метода продажи (Method) и типа объекта (Type), по столбцам — наименование региона (Regionname), а на пересечении строк и столбцов будет стоять медианная цена объекта (Price):

# %%
melb_df.pivot_table(
    values='Price',
    index=['Method','Type'],
    columns='Regionname',
    aggfunc='median',
    fill_value=0
)
# Out:
# C:\Users\g-022\AppData\Local\Temp\ipykernel_1316\1809242545.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   melb_df.pivot_table(
# Regionname        Eastern Metropolitan  Eastern Victoria  \
# Method Type
# PI     house                 1244000.0          780000.0
#        townhouse              760000.0               0.0
#        unit                   650000.0               0.0
# S      house                 1127000.0          675000.0
#        townhouse              828000.0               0.0
#        unit                   645750.0          492000.0
# SA     house                  932500.0          950000.0
#        townhouse              807500.0               0.0
#        unit                        0.0               0.0
# SP     house                 1050000.0          672500.0
# ...

# %% [markdown]
# 4.2 Составьте сводную таблицу, которая показывает зависимость медианной площади (BuildingArea) здания от типа объекта недвижимости (Type) и количества жилых комнат в доме (Rooms). Для какой комбинации признаков площадь здания наибольшая?
# В качестве ответа запишите эту комбинацию (тип здания, число комнат) через запятую, без пробелов.

# %%
melb_pt = melb_df.pivot_table(values='BuildingArea', 
                              index='Type',
                              columns='Rooms',
                              aggfunc='median',
                              fill_value=0).round(1)
display(melb_pt)
print(f'{melb_pt.index[np.where(melb_pt == melb_pt.max().max())[0]][0]}, \
{melb_pt.columns[np.where(melb_pt == melb_pt.max().max())[1]][0]}')
# Out:
# C:\Users\g-022\AppData\Local\Temp\ipykernel_1316\96851724.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   melb_pt = melb_df.pivot_table(values='BuildingArea',
# Rooms         1      2      3      4      5      6      7      8      10
# Type
# house      126.0  126.0  126.0  141.0  177.0  126.0  216.5  126.0  126.0
# townhouse   88.0  114.0  126.0  159.5  152.0    0.0    0.0    0.0    0.0
# unit        69.5  110.0  126.0  126.0    0.0  171.0    0.0  126.0    0.0
# house, 7

# %% [markdown]
# 4.3 Составьте сводную таблицу, которая показывает зависимость медианной цены объекта недвижимости (Price) от риелторского агентства (SellerG) и типа здания (Type).
# Во вновь созданной таблице найдите агентство, у которого медианная цена для зданий типа unit максимальна. В качестве ответа запишите название этого агентства.

# %%
melb_pt = melb_df.pivot_table(values='Price', 
                              index='SellerG',
                              columns='Type',
                              aggfunc='median',
                              fill_value=0).round()
display(melb_pt)
print(f"{melb_pt.index[np.where(melb_pt['unit'] == melb_pt['unit'].max())][0]}")
# Out:
# C:\Users\g-022\AppData\Local\Temp\ipykernel_1316\3866104418.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   melb_pt = melb_df.pivot_table(values='Price',
# Type               house  townhouse      unit
# SellerG
# Alexkarbon     1036250.0   935000.0  560000.0
# Barry           830000.0   727500.0  502000.0
# Bells           692500.0   430500.0  457500.0
# Biggin         1151750.0   675000.0  548000.0
# Brad            875000.0   700000.0  465000.0
# Buckingham      830000.0   820000.0  553000.0
# Burnham         922500.0        0.0  305000.0
# Buxton         1323750.0  1030000.0  670000.0
# C21             836500.0   768750.0  625500.0
# Cayzer         1505000.0  1450000.0  707500.0
# Chisholm       1520000.0   950000.0  640000.0
# Collins        1566500.0   930000.0  592000.0
# ...

# %% [markdown]
# ## Объединение DataFrame
#
# В этой части модуля мы будем работать с популярным датасетом MovieLens, в котором собраны логи некоторой рекомендательной системы фильмов.
# - ratings1 и ratings2 — таблицы с данными о выставленных пользователями оценках фильмов. Они имеют одинаковую структуру и типы данных — на самом деле это две части одной таблицы с оценками фильмов.
#
#     - userId — уникальный идентификатор пользователя, который выставил оценку;
#     - movieId — уникальный идентификатор фильма;
#     - rating — рейтинг фильма.
#     - dates — таблица с датами выставления всех оценок.
#
# - date — дата и время выставления оценки фильму.
# - movies — таблица с информацией о фильмах.
#
#     - movieId — уникальный идентификатор фильма;
#     - title — название фильма и год его выхода;
#     - genres — жанры фильма.

# %%
ratings1_df = pd.read_csv('./data/ratings1.csv')
ratings2_df = pd.read_csv('./data/ratings2.csv')
dates_df = pd.read_csv('./data/dates.csv')
movies_df = pd.read_csv('./data/movies.csv')
display(ratings1_df.head())
ratings1_df.info()
display(ratings2_df.head())
ratings2_df.info()
display(dates_df.head())
dates_df.info()
display(movies_df.head())
movies_df.info()
# Out:
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0
# 2       1        6     4.0
# 3       1       47     5.0
# 4       1       50     5.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40001 entries, 0 to 40000
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   userId   40001 non-null  int64
#  1   movieId  40001 non-null  int64
#  2   rating   40001 non-null  float64
# dtypes: float64(1), int64(2)
# memory usage: 937.6 KB
#    userId  movieId  rating
# 0     274     5621     2.0
# 1     274     5630     3.0
# 2     274     5667     3.5
# 3     274     5679     3.5
# 4     274     5690     3.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60836 entries, 0 to 60835
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   userId   60836 non-null  int64
#  1   movieId  60836 non-null  int64
# ...

# %% [markdown]
# 5.2 Сколько уникальных (по названию) фильмов представлено в таблице movies?

# %%
movies_df['title'].nunique()
# Out:
# 9737

# %% [markdown]
# 5.3 Сколько уникальных пользователей в таблице ratings1?

# %%
ratings1_df['userId'].nunique()
# Out:
# 274

# %% [markdown]
# 5.4 В каком году было выставлено больше всего оценок?
# Для ответа на этот вопрос используйте таблицу dates.

# %%
dates_df['date'] = pd.to_datetime(dates_df['date'], dayfirst=False)
dates_df['date'].dt.year.value_counts().sort_values(ascending=False).index[0]
#dates_df['date'].dt.year.value_counts().index[np.where(dates_df['date'].dt.year.value_counts() \
#                                                       == dates_df['date'].dt.year.value_counts().max())][0]
# Out:
# np.int32(2000)

# %% [markdown]
# Итак, давайте склеим  ratings1 и ratings2 по строкам, так как они имеют одинаковую структуру столбцов. Для этого передадим их списком в функцию concat(). Помним, что параметр axis по умолчанию равен 0, объединение происходит по строкам, поэтому не трогаем его.

# %%
ratings = pd.concat(
    [ratings1_df, ratings2_df],
    ignore_index=True
)
ratings = ratings.drop_duplicates(ignore_index=True)
print('Число строк в таблице ratings: ', ratings.shape[0])
display(ratings)
# Out:
# Число строк в таблице ratings:  100836
#         userId  movieId  rating
# 0            1        1     4.0
# 1            1        3     4.0
# 2            1        6     4.0
# 3            1       47     5.0
# 4            1       50     5.0
# ...        ...      ...     ...
# 100831     610   166534     4.0
# 100832     610   168248     5.0
# 100833     610   168250     5.0
# 100834     610   168252     5.0
# 100835     610   170875     3.0
#
# [100836 rows x 3 columns]

# %% [markdown]
# Наконец, мы можем добавить к нашей таблице с оценками даты их выставления. Для этого конкатенируем таблицы ratings и dates по столбцам

# %%
ratings_dates = pd.concat([ratings, dates_df], axis=1)
display(ratings_dates.tail(7))
# Out:
#         userId  movieId  rating                date
# 100829     610   164179     5.0 2017-05-03 21:07:11
# 100830     610   166528     4.0 2017-05-04 06:29:25
# 100831     610   166534     4.0 2017-05-03 21:53:22
# 100832     610   168248     5.0 2017-05-03 22:21:31
# 100833     610   168250     5.0 2017-05-08 19:50:47
# 100834     610   168252     5.0 2017-05-03 21:19:12
# 100835     610   170875     3.0 2017-05-03 21:20:15

# %% [markdown]
# ## 8. Закрепление знаний

# %% [markdown]
# Результат нашего объединения таблиц с рейтингами вы можете найти в ratings_movies.csv
#
# Для решения задач нам понадобится выделить из признака title год выпуска фильма. Для этого напишем функцию get_year_release(arg).

# %%
#библиотека для регулярных выражений
import re 
def get_year_release(arg):
    #находим все слова по шаблону "(DDDD)"
    candidates = re.findall(r'\(\d{4}\)', arg) 
    # проверяем число вхождений
    if len(candidates) > 0:
        #если число вхождений больше 0,
	#очищаем строку от знаков "(" и ")"
        year = candidates[0].replace('(', '')
        year = year.replace(')', '')
        return int(year)
    else:
        #если год не указан, возвращаем None
        return None

# %% [markdown]
# Загрузка данных и их преобразование.

# %%
ratings_movies_df = pd.read_csv('./data/ratings_movies.csv')
ratings_movies_df['date'] = pd.to_datetime(ratings_movies_df['date'])
ratings_movies_df['title'] = ratings_movies_df['title'].astype('category')
display(ratings_movies_df.head())
ratings_movies_df.info()
rm_df = ratings_movies_df.copy()
# Out:
#    Unnamed: 0  userId  movieId  rating                date  \
# 0           0       1        1     4.0 2000-07-30 18:45:03
# 1           1       1        3     4.0 2000-07-30 18:20:47
# 2           2       1        6     4.0 2000-07-30 18:37:04
# 3           3       1       47     5.0 2000-07-30 19:03:35
# 4           4       1       50     5.0 2000-07-30 18:48:51
#
#                          title                                       genres
# 0             Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1      Grumpier Old Men (1995)                               Comedy|Romance
# 2                  Heat (1995)                        Action|Crime|Thriller
# 3  Seven (a.k.a. Se7en) (1995)                             Mystery|Thriller
# 4   Usual Suspects, The (1995)                       Crime|Mystery|Thriller
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100836 entries, 0 to 100835
# Data columns (total 7 columns):
#  #   Column      Non-Null Count   Dtype
# ...

# %% [markdown]
# 8.1 Создайте в таблице новый признак year_release, который соответствует году выпуска фильма.
# У скольких фильмов не указан год их выпуска?

# %%
rm_df['year_release'] = rm_df['title'].apply(get_year_release).fillna(0)
rm_df['year_release'] = rm_df['year_release'].astype('int')
#display(rm_df.head())
#rm_df.info()
print(f"Оценок фильмов с неуказанным годом выпуска: {rm_df[rm_df['year_release'] == 0]['movieId'].shape[0]}")
print(f"Фильмов с неуказанным годом выпуска: {len(set(rm_df[rm_df['year_release'] == 0]['movieId']))}")
# Out:
# Оценок фильмов с неуказанным годом выпуска: 18
# Фильмов с неуказанным годом выпуска: 13

# %% [markdown]
# 8.2 Какой фильм, выпущенный в 1999 году, получил наименьшую среднюю оценку зрителей?
# В качестве ответа запишите название этого фильма без указания года его выпуска.

# %%
rm_df[rm_df['year_release'] == 1999].groupby(by='title')['rating'].agg(['mean']).sort_values(by='mean').iloc[0].name.split(' (')[0]
# Out:
# C:\Users\g-022\AppData\Local\Temp\ipykernel_1316\1009213500.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   rm_df[rm_df['year_release'] == 1999].groupby(by='title')['rating'].agg(['mean']).sort_values(by='mean').iloc[0].name.split(' (')[0]
# 'Bloodsport: The Dark Kumite'

# %% [markdown]
# 8.3 Какое сочетание жанров фильмов (genres), выпущенных в 2010 году, получило наименьшую среднюю оценку (rating)?
# Запишите сочетание так же, как оно указано в таблице (через разделитель |, без пробелов).

# %%
rm_df[rm_df['year_release'] == 2010].groupby(by='genres')['rating'].agg(['mean']).sort_values(by='mean').iloc[0].name
# Out:
# 'Action|Sci-Fi'

# %% [markdown]
# 8.4 Какой пользователь (userId) посмотрел наибольшее количество различных (уникальных) комбинаций жанров (genres) фильмов? В качестве ответа запишите идентификатор этого пользователя.

# %%
def get_len_set(x):
    return len(set(x))


rm_df.groupby(by='userId')['genres'].agg(get_len_set).sort_values(ascending=False).index[0]
# Out:
# np.int64(599)

# %% [markdown]
# 8.5 Найдите пользователя, который выставил наименьшее количество оценок, но его средняя оценка фильмам наибольшая.
# В качестве ответа укажите идентификатор этого пользователя.
# Чтобы рассчитать несколько параметров для каждого пользователя (количество оценок и среднюю оценку), можно воспользоваться методом agg() на сгруппированных данных.

# %%
rm_df.groupby(by='userId')['rating'].agg(['count', 'mean']).sort_values(by=['count', 'mean'], ascending=[True, False]).index[0]
# Out:
# np.int64(53)

# %% [markdown]
# 8.6 Найдите сочетание жанров (genres) за 2018 год, которое имеет наибольший средний рейтинг (среднее по столбцу rating), и при этом число выставленных ему оценок (количество значений в столбце rating) больше 10.
# Запишите сочетание так же, как оно указано в таблице (через разделитель |, без пробелов).

# %%
x = rm_df[rm_df['year_release'] == 2018].groupby(by='genres')['rating'].agg(['mean', 'count']).sort_values(by='mean', ascending=False)
x[x['count'] > 10].index[0]
# Out:
# 'Action|Adventure|Sci-Fi'

# %% [markdown]
# 8.7 Добавьте в таблицу новый признак year_rating — год выставления оценки. Создайте сводную таблицу, которая иллюстрирует зависимость среднего рейтинга фильма от года выставления оценки и жанра. Выберите верные варианты ответа, исходя из построенной таблицы:
#
# - A За весь период (с 1996 по 2018 год) сочетание жанров Action|Adventure ни разу не получало среднюю оценку ниже 3.
# - B Наилучшую оценку жанр Action|Adventure|Animation|Children|Comedy|IMAX получил в 2010 году.
# - C Среди сочетаний жанров, получивших наивысшую среднюю оценку в 2018 году, есть сочетание Animation|Children|Mystery.
# - D Для жанра Comedy прослеживается тенденция падения рейтинга с каждым годом (с 1996 по 2018).

# %%
rm_df['year_rating'] = rm_df['date'].dt.year
pt_rm_df = rm_df.pivot_table(values='rating', index='genres', columns='year_rating').round(1)
#display(pt_rm_df)
print(f"A: {np.where(pt_rm_df[:].loc['Action|Adventure'] > 3, True, False).all()}")

print(f"B: {pt_rm_df[:].loc['Action|Adventure|Animation|Children|Comedy|IMAX'].sort_values(ascending=False).index[0] == 2010}")

print(f"C: {'Animation|Children|Mystery' in pt_rm_df[pt_rm_df[2018] == pt_rm_df[2018].max()].index}")

pt_rm_df[:].loc['Comedy']
# Out:
# A: True
# B: False
# C: True
# year_rating
# 1996    3.2
# 1997    3.4
# 1998    3.0
# 1999    3.6
# 2000    3.1
# 2001    3.3
# 2002    3.2
# 2003    3.1
# 2004    3.4
# 2005    3.0
# 2006    3.3
# 2007    2.9
# 2008    3.4
# 2009    3.3
# 2010    3.2
# 2011    3.2
# 2012    3.5
# 2013    3.5
# 2014    3.3
# 2015    3.1
# 2016    3.4
# 2017    2.9
# 2018    3.1
# Name: Comedy, dtype: float64

# %% [markdown]
# Дано два файла:
#
# - orders.csv, содержащий данные о заказах;
# - products.csv, содержащий данные о товарах.
# Прочитайте данные файлы, посмотрите на содержимое таблиц и проанализируйте его.
#
# Подумайте, как связаны данные таблицы (какими ключевыми столбцами).
#
# Объедините заданные таблицы в таблицу orders_products, чтобы в результирующей таблице оказалась информация обо всех заказах, но не оказалось информации о продуктах, на которых заказов ещё не поступало.

# %%
orders = pd.read_csv('./data/orders.csv', sep=';')
products = pd.read_csv('./data/products.csv', sep=';')
display(orders)
orders.info()
display(products)
products.info()
orders_products = orders.merge(products, left_on='ID товара', right_on='Product_ID', how='left')
display(orders_products)
orders_products.info()
# Out:
#           Дата создания  Order ID  ID Покупателя  \
# 0   09.11.2019 21:55:51         9             10
# 1   09.11.2019 15:05:57         8              9
# 2   09.11.2019 15:05:57         8              9
# 3   09.11.2019 12:50:07         7              8
# 4   09.11.2019 12:00:00         6              1
# 5   09.11.2019 12:00:00         6              1
# 6   08.11.2019 08:36:22         5              5
# 7   08.11.2019 08:36:22         4              9
# 8   08.11.2019 08:36:22         3              8
# 9   08.11.2019 08:36:22         3              8
# 10  08.11.2019 08:36:21         2              7
# 11  08.11.2019 08:36:21         2              7
# 12  08.11.2019 08:36:21         2              7
# 13  08.11.2019 08:36:21         2              7
# 14  08.11.2019 08:36:20         1              5
# 15  08.11.2019 08:36:20         1              5
# 16  08.11.2019 08:36:20         1              5
# 17  01.01.2001 00:00:00         0              1
#
# ...

# %% [markdown]
# 8.8 Какой идентификатор (Order ID) имеет заказ, для которого не оказалось информации о товаре?

# %%
orders_products[pd.isnull(orders_products['Product_ID'])]['Order ID']
# Out:
# 17    0
# Name: Order ID, dtype: int64

# %% [markdown]
# 8.9 На какой товар была произведена отмена?
# В качестве ответа запишите название этого товара (Name).

# %%
orders_products[orders_products['Статус'] == 'Отменён']['Name']
# Out:
# 6    Носки беговые Camino
# Name: Name, dtype: object

# %% [markdown]
# 8.10 Какой покупатель принёс наибольшую суммарную прибыль интернет-магазину за указанный период?
# В ответ запишите идентификатор этого покупателя (ID Покупателя).
# Прибыль состоит только из оплаченных заказов и рассчитывается как количество купленного товара, умноженное на его цену.

# %%
orders_products['Оплачен'] = np.where(orders_products['Оплачен'] == 'Да', True, False)
orders_products['costing'] = orders_products['Количество'] * orders_products['Price']
orders_products.groupby('ID Покупателя')['costing'].sum().sort_values(ascending=False).index[0]
# Out:
# np.int64(7)
